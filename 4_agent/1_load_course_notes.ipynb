# %%
import json

course_notes = "2_prompting/results_module1_per_video_so/llm_response_CeukwyUdaz8.json"
course_notes_path = f"../{course_notes}"

# %%
from pathlib import Path

notes_path = "../2_prompting/results_module1_per_video_so"

paths = [p for p in Path(notes_path).iterdir()]

# %%
import json 
with open(file=paths[0], mode="r", encoding="utf-8") as f:
    notes = json.load(f)

# %%
# load course notes
with open(file=course_notes_path, mode="r", encoding="utf-8") as f:
    notes = json.load(f)

# %%
notes["title"]
# Out:
# 'Rule-based vs Machine Learning Systems — Spam Detection Case Study'

# %%
type(notes)
# Out:
# dict

# %%
import json
from pathlib import Path
from typing import Any

# %%
# write simple tool - load course notes
def load_course_notes(notes_path: str) -> dict[str, Any]:
    path = Path(notes_path)

    if not path.exists():
        raise FileNotFoundError(f"File does not exist: {notes_path}")
    
    notes = json.loads(paths[0].read_text(encoding="utf-8"))
    
    return notes

# %%
# Out:
# dict

# %%
import json
from datetime import datetime, timezone
from pathlib import Path
from typing import Any


LOG_PATH = Path("tool_calls.jsonl")


def log_tool_call(
    tool_name: str,
    success: bool,
    notes_path: str | None = None,
    error: str | None = None,
) -> None:
    
    LOG_PATH.parent.mkdir(parents=True, exist_ok=True)

    event = {
        "timestamp": datetime.now(timezone.utc).isoformat(),
        "tool_name": tool_name,
        "success": success,
        "json_path": notes_path,
        "error": error,
    }

    with LOG_PATH.open("a", encoding="utf-8") as f:
        f.write(json.dumps(event, ensure_ascii=False) + "\n")

# %%
# add error logging
def load_course_notes(notes_path: str) -> dict[str, Any]:

    try:
        path = Path(notes_path)

        if not path.exists():
            raise FileNotFoundError(f"File does not exist: {notes_path}")
        
        notes = json.loads(notes_path.read_text(encoding="utf-8"))

        log_tool_call(
            tool_name="load_course_notes",
            success=True,
            notes_path=str(path),
        )
        return notes
    
    except Exception as e:
        log_tool_call(
            tool_name="load_course_notes",
            success=False,
            notes_path=str(path),
            error=str(e)
        )
    
        raise

# %%
json.loads(paths[0].read_text(encoding="utf-8"))

# %%
Path(paths[0])
# Out:
# PosixPath('../2_prompting/results_module1_per_video_so/llm_response_VRrEEVeJ440.json')

# %%
load_course_notes(paths[0])
# Out:
# {'title': 'Introductory Machine Learning: Concepts, NumPy, Linear Algebra, and pandas — Session Summary',
#  'overview': 'Compact, practical reference covering the session: a conceptual introduction to supervised machine learning using a car-price prediction example; comparison with rule-based systems; the ML lifecycle; model selection and train/validation/test splitting; environment setup guidance; practical Python tooling (NumPy and pandas); and linear algebra foundations relevant to ML. This document converts spoken explanations into concise study notes, code snippets, diagrams, and targeted screenshot recommendations for learners.',
#  'key_concepts': [{'title': 'Features vs Target (X and y)',
#    'description': 'Features (X) are all known attributes about an example; the target (y) is the variable we want to predict.',
#    'bullet_points': ['Features: inputs to the model (numerical or categorical attributes of a car).',
# ...
